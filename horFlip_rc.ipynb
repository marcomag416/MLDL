# %%
import os
import pandas as pd
from PIL import Image
import sys
import requests
from zipfile import ZipFile
from io import BytesIO

# %%
#install and import wandb for data collecting
# !pip install wandb
import wandb

wandb.login()
# Out:
# Requirement already satisfied: wandb in c:\users\luca\pycharmprojects\mldl\venv\lib\site-packages (0.16.6)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in c:\users\luca\pycharmprojects\mldl\venv\lib\site-packages (from wandb) (8.1.7)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in c:\users\luca\pycharmprojects\mldl\venv\lib\site-packages (from wandb) (3.1.43)
# Requirement already satisfied: requests<3,>=2.0.0 in c:\users\luca\pycharmprojects\mldl\venv\lib\site-packages (from wandb) (2.31.0)
# Requirement already satisfied: psutil>=5.0.0 in c:\users\luca\pycharmprojects\mldl\venv\lib\site-packages (from wandb) (5.9.8)
# Requirement already satisfied: sentry-sdk>=1.0.0 in c:\users\luca\pycharmprojects\mldl\venv\lib\site-packages (from wandb) (1.45.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in c:\users\luca\pycharmprojects\mldl\venv\lib\site-packages (from wandb) (0.4.0)
# Requirement already satisfied: PyYAML in c:\users\luca\pycharmprojects\mldl\venv\lib\site-packages (from wandb) (6.0.1)
# Requirement already satisfied: setproctitle in c:\users\luca\pycharmprojects\mldl\venv\lib\site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in c:\users\luca\pycharmprojects\mldl\venv\lib\site-packages (from wandb) (65.5.1)
# Requirement already satisfied: appdirs>=1.4.3 in c:\users\luca\pycharmprojects\mldl\venv\lib\site-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in c:\users\luca\pycharmprojects\mldl\venv\lib\site-packages (from wandb) (4.25.3)
# Requirement already satisfied: colorama in c:\users\luca\pycharmprojects\mldl\venv\lib\site-packages (from Click!=8.0.0,>=7.1->wandb) (0.4.6)
# Requirement already satisfied: six>=1.4.0 in c:\users\luca\pycharmprojects\mldl\venv\lib\site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\luca\pycharmprojects\mldl\venv\lib\site-packages (from GitPython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\luca\pycharmprojects\mldl\venv\lib\site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\luca\pycharmprojects\mldl\venv\lib\site-packages (from requests<3,>=2.0.0->wandb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\luca\pycharmprojects\mldl\venv\lib\site-packages (from requests<3,>=2.0.0->wandb) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\luca\pycharmprojects\mldl\venv\lib\site-packages (from requests<3,>=2.0.0->wandb) (2024.2.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\luca\pycharmprojects\mldl\venv\lib\site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# [notice] A new release of pip is available: 24.0 -> 24.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# wandb: Currently logged in as: luca-porta (porta-luca). Use `wandb login --relogin` to force relogin
# True

# %%
#download and extract project repository

url= "https://github.com/marcomag416/MLDL/archive/refs/heads/main.zip"

# Send a GET request to the URL
response = requests.get(url)
# Check if the request was successful
if response.status_code == 200:
    #print(response.content)
    # Open the downloaded bytes and extract them
    with ZipFile(BytesIO(response.content)) as zip_file:
        zip_file.extractall('./')
    print('Download and extraction complete!')

sys.path.insert(0, './MLDL-main')
# Out:
# Download and extraction complete!

# %%
cityscape_dataset_path = "./dataset/Cityscapes/Cityspaces"
# Define paths
gta_dataset_path = "./dataset/"
images_path = gta_dataset_path + 'GTA5/images'
labels_path = gta_dataset_path + 'GTA5/labels'

# %%
# Initialize lists to hold data
data = []

# Load images and corresponding masks
for image_filename in os.listdir(images_path):
    if image_filename.endswith('.png'):
        image_path = os.path.join(images_path, image_filename)
        mask_path = os.path.join(labels_path, image_filename)

        # Check if corresponding mask file exists
        if os.path.exists(mask_path):
            # Open image and mask to ensure they can be loaded (optional, for validation)
            try:
                image = Image.open(image_path)
                mask = Image.open(mask_path)

                # Add data to list
                data.append({
                    'image_path': image_path,
                    'mask_path': mask_path
                })
            except Exception as e:
                print(f"Error loading {image_path} or {mask_path}: {e}")

# Create a DataFrame from the data list
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv('./gta5_segmentation_dataset.csv', index=False)

print("Semantic segmentation dataset created and saved as 'gta5_segmentation_dataset.csv'")
# Out:
# Semantic segmentation dataset created and saved as 'gta5_segmentation_dataset.csv'

# %%
#import from packages
import numpy as np
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as T
import albumentations as A
from albumentations.pytorch import ToTensorV2
from torch import nn
from torch.optim.lr_scheduler import PolynomialLR
from timeit import default_timer as timer
from torch.autograd import Variable

#other imports
from pytorchdl_gta5.labels import GTA5Labels_TaskCV2017
from models.bisenet.build_bisenet import BiSeNet
from models.domainAdaptationModule import DomainAdaptationModule

# Setup device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"

# Set the manual seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)
# Out:
# INFO:albumentations.check_version:A new version of Albumentations is available: 1.4.10 (you have 1.4.7). Upgrade using: pip install --upgrade albumentations

# %%
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as T
import albumentations as A
from albumentations.pytorch import ToTensorV2
from pytorchdl_gta5.labels import GTA5Labels_TaskCV2017

if __name__ != '__main__':
    raise Exception("This script should not be imported; it should be run directly.")

# Setup device agnostic code
device = "cuda" if torch.cuda.is_available() else "cpu"

# Define the custom dataset class
class GTASegmentationDataset(Dataset):
    def __init__(self, csv_file, transform=None):
        self.data_frame = pd.read_csv(csv_file)
        self.transform = transform
        self.label_mapping = self._create_label_mapping()

    def __len__(self):
        return len(self.data_frame)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_name = self.data_frame.iloc[idx, 0]
        mask_name = self.data_frame.iloc[idx, 1]

        image = Image.open(img_name).convert('RGB')
        mask = Image.open(mask_name).convert('RGB')

        if self.transform:
            augmented = self.transform(image=np.array(image), mask=np.array(mask))
            image, mask = augmented['image'], augmented['mask']

        mask = self._map_mask(np.array(mask))

        if self.transform:
            # Convert mask to tensor without normalization
            mask = torch.from_numpy(mask).permute(2, 0, 1).float()
            mask = mask[0]

        return image, mask

    def _create_label_mapping(self):
        label_mapping = {label.color: label.ID for label in GTA5Labels_TaskCV2017.list_}
        label_mapping[(0, 0, 0)] = 255  # Ensure unmapped colors go to 'unlabeled'
        return label_mapping

    def _map_mask(self, mask):
        new_mask = np.zeros_like(mask)
        for color, label_id in self.label_mapping.items():
            color_mask = np.all(mask == color, axis=-1)
            new_mask[color_mask] = label_id  # Use label_id instead of color
        return new_mask



# Define paths
csv_file = './gta5_segmentation_dataset.csv'

# Define image transformations
transform = A.Compose([
    A.Resize(720, 1280),
    A.HorizontalFlip(p=0.5),
    A.OneOf([
        A.RandomResizedCrop(height=720, width=1280, scale=(0.8, 1.0)),
        A.NoOp()
    ], p=0.5),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
    ToTensorV2()
])

# Create the dataset and dataloader
train_dataset = GTASegmentationDataset(csv_file=csv_file, transform=transform)

# %%
class Cityscapes(Dataset):
    def __init__(self, root_dir, split, transforms=None, label_type='gtFine_labelTrainIds'):
        self.root_dir = root_dir
        self.split = split
        self.transforms = transforms
        self.label_type = label_type

        self.images_dir = f"{root_dir}/images/{split}"
        self.labels_dir = f"{root_dir}/gtFine/{split}"

        self.image_paths = []
        self.label_paths = []

        # Manually iterate over directories
        cities = [city for city in os.listdir(self.images_dir) if os.path.isdir(f"{self.images_dir}/{city}")]
        for city in cities:
            img_dir_city = f"{self.images_dir}/{city}"
            lbl_dir_city = f"{self.labels_dir}/{city}"

            if not os.path.isdir(img_dir_city) or not os.path.isdir(lbl_dir_city):
                continue

            for img_file in os.listdir(img_dir_city):
                if img_file.endswith('_leftImg8bit.png'):
                    img_path = f"{img_dir_city}/{img_file}"
                    lbl_file = img_file.replace('_leftImg8bit.png', f'_{self.label_type}.png')
                    lbl_path = f"{lbl_dir_city}/{lbl_file}"

                    if os.path.isfile(img_path) and os.path.isfile(lbl_path):
                        self.image_paths.append(img_path)
                        self.label_paths.append(lbl_path)
                    else:
                        print(f"Warning: Image or label file not found for {img_file}")

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        lbl_path = self.label_paths[idx]

        image = Image.open(img_path).convert('RGB')
        label = Image.open(lbl_path)

        image = np.array(image)
        label = np.array(label)

        if self.transforms:
            augmented = self.transforms(image=image, mask=label)
            image, label = augmented['image'], augmented['mask']

        return image, label


# Example usage
image_transforms = A.Compose([
    A.Resize(512, 1024),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
    ToTensorV2()
])

val_dataset = Cityscapes(root_dir=cityscape_dataset_path, split='val', transforms=image_transforms)


print(f"Val_Dataset size: {len(val_dataset)}")
# Out:
# Val_Dataset size: 500

# %%
def train(model, optimizer_train, dataloader, loss_fn_train):
    model.train()  # Set the model to training mode
    train_loss = 0.0
    total = 0

    for idx, (inputs_train, targets_train) in enumerate(dataloader):
        inputs_train = inputs_train.to(device)
        targets_train = targets_train.to(device, dtype=torch.long)  # Move data to the appropriate device

        optimizer_train.zero_grad()  # Zero out gradients from the previous iteration
        outputs_train, _, _ = model(inputs_train)  # Forward pass
        # print( "train")
        loss = loss_fn_train(outputs_train, targets_train)  # Calculate the loss

        loss.backward()  # Backward pass
        optimizer_train.step()  # Update the weights

        wandb.log({"train/Batch loss": loss})

        train_loss += loss.item() * inputs_train.size(0)  # Accumulate the total loss
        _, predicted_train = outputs_train.max(1)
        total += targets_train.size(0)

    # Calculate average loss for the epoch
    avg_loss = train_loss / total

    wandb.log({"train/Epoch loss": avg_loss})

    return avg_loss


def compute_iou(pred, target, num_classes):
    ious = []
    pred = pred.view(-1)
    target = target.view(-1)

    for cls in range(num_classes):
        pred_inds = (pred == cls)
        target_inds = (target == cls)
        intersection = (pred_inds[target_inds]).sum().item()
        union = pred_inds.sum().item() + target_inds.sum().item() - intersection
        if union == 0:
            ious.append(float('nan'))  # If there is no union, set IoU to NaN
        else:
            ious.append(intersection / union)

    return np.array(ious)

def eval(model, dataloader, loss_fn, device, num_classes=19):
    model.eval()  # Set the model to evaluation mode
    test_loss = 0.0
    total = 0
    all_ious = []  # List to store IoUs for each batch

    with torch.no_grad():  # Disable gradient calculation during inference
        for inputs_test, targets_test in dataloader:
            inputs_test, targets_test = inputs_test.to(device), targets_test.to(device, dtype=torch.long)

            outputs_test = model(inputs_test)  # Forward pass
            loss = loss_fn(outputs_test, targets_test)  # Calculate the loss

            test_loss += loss.item() * inputs_test.size(0)  # Accumulate the total loss
            _, predicted_test = outputs_test.max(1)
            total += targets_test.size(0)

            # Compute IoU for this batch
            batch_ious = compute_iou(predicted_test, targets_test, num_classes)
            all_ious.append(batch_ious)

    # Calculate average loss
    avg_loss = test_loss / total

    wandb.log({})

    # Calculate mean IoU
    all_ious = np.array(all_ious)
    mean_iou = np.nanmean(all_ious, axis=0)  # Mean IoU for each class
    miou = np.nanmean(mean_iou)  # Mean IoU across all classes

    wandb.log({"val/Validation loss": avg_loss, "val/mIoU": miou})

    return avg_loss, miou, mean_iou

# %%
from build_bisenet import BiSeNet
from torch import nn
from torch.optim.lr_scheduler import PolynomialLR


# Set CUDA_LAUNCH_BLOCKING environment variable
os.environ['CUDA_LAUNCH_BLOCKING']="1"
os.environ['TORCH_USE_CUDA_DSA'] = "1"

context_path = 'resnet18'

#save hyperparameters
config = {
    "learning_rate": 1e-3,
    "max_epochs": 50,
    "batch_size": 8,
    "weight_decay": "None",
    "dataset": "Cityscapes",
    "scheduler": "None",
    "optimizer": "Adam",
    "transformations": "gaussian blur, horizontal flip"
}


# create dataloaders
train_dataloader = DataLoader(train_dataset, batch_size=config["batch_size"], shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=config["batch_size"], shuffle=False)

# Initialize the model
model = BiSeNet(num_classes=19, context_path=context_path).to(device)

loss_fn = nn.CrossEntropyLoss(ignore_index=255)
optimizer = torch.optim.Adam(model.parameters(), lr=config["learning_rate"])
#scheduler = PolynomialLR(optimizer, total_iters=config["max_epochs"], power=config["polyPower"])
scheduler = None

# %%
from timeit import default_timer as timer

#run names
project_name = "bisenet_gta"
run_name = "horizFlip_rc"

#start wandb run
wandb.init(project=project_name, name=run_name, config=config)

start_time = timer()

top_miou = 0

"""
# Setup training and save the results
for epoch in range(config["max_epochs"]):
    wandb.log({"Epoch": epoch+1})
    train(model, optimizer, train_dataloader, loss_fn)
    avg_loss, miou, mean_iou = eval(model, val_dataloader, loss_fn, device=device)
    if scheduler != None:
      scheduler.step()
    #save model state every 5 epochs
    if(top_miou < miou):
      torch.save(model.state_dict(), f"./drive/MyDrive/Colab Notebooks/model_weights/{project_name}/{run_name}_epoch{epoch}.pth")
    print(f"Epoch: {epoch+1}, Loss: {avg_loss}, mIoU: {miou*100:.2f}%")
    for i, value in enumerate(mean_iou):
        print(f"Class: {i}, mIoU: {value:.4f}")
"""

# Define the subfolder name
subfolder_name = "model_states"

# Create the subfolder if it doesn't exist
os.makedirs(subfolder_name, exist_ok=True)

for epoch in range(config["max_epochs"]):
    wandb.log({"Epoch": epoch+1})
    train(model, optimizer, train_dataloader, loss_fn)
    avg_loss, miou, mean_iou = eval(model, val_dataloader, loss_fn, device=device)
    if scheduler != None:
        scheduler.step()
    # Save model state every 5 epochs
    if top_miou < miou:
        top_miou = miou
        model_path = os.path.join(subfolder_name, f"{project_name}_{run_name}_epoch{epoch}.pth")
        torch.save(model.state_dict(), model_path)
    print(f"Epoch: {epoch+1}, Loss: {avg_loss}, mIoU: {miou*100:.2f}%")
    for i, value in enumerate(mean_iou):
        print(f"Class: {i}, mIoU: {value:.4f}")


# End the timer and print out how long it took
end_time = timer()
print(f"[INFO] Total training time: {end_time - start_time:.3f} seconds")
wandb.finish()
# Out:
# wandb version 0.17.3 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.16.6
# Run data is saved locally in <code>C:\Users\Luca\PycharmProjects\MLDL\Project\testingMIOU\wandb\run-20240629_135848-bp6xowec</code>
# Syncing run <strong><a href='https://wandb.ai/porta-luca/bisenet_gta/runs/bp6xowec' target="_blank">horizFlip_rc</a></strong> to <a href='https://wandb.ai/porta-luca/bisenet_gta' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/porta-luca/bisenet_gta' target="_blank">https://wandb.ai/porta-luca/bisenet_gta</a>
#  View run at <a href='https://wandb.ai/porta-luca/bisenet_gta/runs/bp6xowec' target="_blank">https://wandb.ai/porta-luca/bisenet_gta/runs/bp6xowec</a>
# Epoch: 1, Loss: 1.1899481496810913, mIoU: 15.42%
# Class: 0, mIoU: 0.5754
# Class: 1, mIoU: 0.0432
# Class: 2, mIoU: 0.4949
# Class: 3, mIoU: 0.0299
# Class: 4, mIoU: 0.0002
# Class: 5, mIoU: 0.0146
# Class: 6, mIoU: 0.0007
# Class: 7, mIoU: 0.0000
# Class: 8, mIoU: 0.6398
# Class: 9, mIoU: 0.1128
# Class: 10, mIoU: 0.6099
# Class: 11, mIoU: 0.0000
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.3927
# Class: 14, mIoU: 0.0149
# Class: 15, mIoU: 0.0012
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 2, Loss: 1.5911398525238036, mIoU: 12.81%
# Class: 0, mIoU: 0.3050
# Class: 1, mIoU: 0.0379
# Class: 2, mIoU: 0.4399
# Class: 3, mIoU: 0.0230
# Class: 4, mIoU: 0.0060
# Class: 5, mIoU: 0.0840
# Class: 6, mIoU: 0.0148
# Class: 7, mIoU: 0.0045
# Class: 8, mIoU: 0.5948
# Class: 9, mIoU: 0.0504
# Class: 10, mIoU: 0.6139
# Class: 11, mIoU: 0.0258
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.2116
# Class: 14, mIoU: 0.0219
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 3, Loss: 1.7853216428756713, mIoU: 12.34%
# Class: 0, mIoU: 0.2900
# Class: 1, mIoU: 0.0012
# Class: 2, mIoU: 0.4269
# Class: 3, mIoU: 0.0000
# Class: 4, mIoU: 0.0000
# Class: 5, mIoU: 0.0859
# Class: 6, mIoU: 0.0081
# Class: 7, mIoU: 0.0233
# Class: 8, mIoU: 0.6453
# Class: 9, mIoU: 0.0616
# Class: 10, mIoU: 0.6417
# Class: 11, mIoU: 0.0086
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.1406
# Class: 14, mIoU: 0.0115
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 4, Loss: 2.191502866744995, mIoU: 14.30%
# Class: 0, mIoU: 0.2295
# Class: 1, mIoU: 0.0610
# Class: 2, mIoU: 0.5148
# Class: 3, mIoU: 0.0321
# Class: 4, mIoU: 0.0040
# Class: 5, mIoU: 0.0582
# Class: 6, mIoU: 0.0938
# Class: 7, mIoU: 0.0783
# Class: 8, mIoU: 0.6836
# Class: 9, mIoU: 0.0949
# Class: 10, mIoU: 0.5142
# Class: 11, mIoU: 0.1889
# Class: 12, mIoU: 0.0122
# Class: 13, mIoU: 0.1290
# Class: 14, mIoU: 0.0220
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 5, Loss: 1.864527250289917, mIoU: 11.50%
# Class: 0, mIoU: 0.3052
# Class: 1, mIoU: 0.0093
# Class: 2, mIoU: 0.4167
# Class: 3, mIoU: 0.0390
# Class: 4, mIoU: 0.0000
# Class: 5, mIoU: 0.0650
# Class: 6, mIoU: 0.0399
# Class: 7, mIoU: 0.0028
# Class: 8, mIoU: 0.5667
# Class: 9, mIoU: 0.0289
# Class: 10, mIoU: 0.5542
# Class: 11, mIoU: 0.0749
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.0711
# Class: 14, mIoU: 0.0121
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 6, Loss: 1.2333573031425475, mIoU: 15.12%
# Class: 0, mIoU: 0.4603
# Class: 1, mIoU: 0.0629
# Class: 2, mIoU: 0.4514
# Class: 3, mIoU: 0.0266
# Class: 4, mIoU: 0.0379
# Class: 5, mIoU: 0.0507
# Class: 6, mIoU: 0.0397
# Class: 7, mIoU: 0.0428
# Class: 8, mIoU: 0.6354
# Class: 9, mIoU: 0.0643
# Class: 10, mIoU: 0.5803
# Class: 11, mIoU: 0.0474
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.3640
# Class: 14, mIoU: 0.0088
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 7, Loss: 1.3621437101364136, mIoU: 16.79%
# Class: 0, mIoU: 0.3657
# Class: 1, mIoU: 0.0866
# Class: 2, mIoU: 0.6410
# Class: 3, mIoU: 0.0579
# Class: 4, mIoU: 0.0123
# Class: 5, mIoU: 0.0910
# Class: 6, mIoU: 0.0379
# Class: 7, mIoU: 0.0447
# Class: 8, mIoU: 0.6268
# Class: 9, mIoU: 0.0327
# Class: 10, mIoU: 0.6310
# Class: 11, mIoU: 0.1963
# Class: 12, mIoU: 0.0031
# Class: 13, mIoU: 0.3373
# Class: 14, mIoU: 0.0262
# Class: 15, mIoU: 0.0003
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 8, Loss: 1.307091718673706, mIoU: 15.44%
# Class: 0, mIoU: 0.4914
# Class: 1, mIoU: 0.0286
# Class: 2, mIoU: 0.5491
# Class: 3, mIoU: 0.0076
# Class: 4, mIoU: 0.0010
# Class: 5, mIoU: 0.0511
# Class: 6, mIoU: 0.0894
# Class: 7, mIoU: 0.0253
# Class: 8, mIoU: 0.6540
# Class: 9, mIoU: 0.1037
# Class: 10, mIoU: 0.4799
# Class: 11, mIoU: 0.1223
# Class: 12, mIoU: 0.0020
# Class: 13, mIoU: 0.3048
# Class: 14, mIoU: 0.0231
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0002
# Class: 18, mIoU: 0.0000
# Epoch: 9, Loss: 1.1783716535568238, mIoU: 17.34%
# Class: 0, mIoU: 0.4882
# Class: 1, mIoU: 0.0477
# Class: 2, mIoU: 0.5927
# Class: 3, mIoU: 0.0460
# Class: 4, mIoU: 0.0162
# Class: 5, mIoU: 0.0427
# Class: 6, mIoU: 0.0119
# Class: 7, mIoU: 0.0703
# Class: 8, mIoU: 0.6887
# Class: 9, mIoU: 0.0473
# Class: 10, mIoU: 0.6045
# Class: 11, mIoU: 0.1681
# Class: 12, mIoU: 0.0002
# Class: 13, mIoU: 0.4386
# Class: 14, mIoU: 0.0246
# Class: 15, mIoU: 0.0060
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0003
# Class: 18, mIoU: 0.0000
# Epoch: 10, Loss: 2.031361967086792, mIoU: 13.47%
# Class: 0, mIoU: 0.2365
# Class: 1, mIoU: 0.0100
# Class: 2, mIoU: 0.4703
# Class: 3, mIoU: 0.0186
# Class: 4, mIoU: 0.0086
# Class: 5, mIoU: 0.0548
# Class: 6, mIoU: 0.0708
# Class: 7, mIoU: 0.0699
# Class: 8, mIoU: 0.6182
# Class: 9, mIoU: 0.0326
# Class: 10, mIoU: 0.5809
# Class: 11, mIoU: 0.1094
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.2592
# Class: 14, mIoU: 0.0199
# Class: 15, mIoU: 0.0002
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 11, Loss: 1.5580744581222534, mIoU: 14.47%
# Class: 0, mIoU: 0.3025
# Class: 1, mIoU: 0.0218
# Class: 2, mIoU: 0.5654
# Class: 3, mIoU: 0.0186
# Class: 4, mIoU: 0.0215
# Class: 5, mIoU: 0.0817
# Class: 6, mIoU: 0.0250
# Class: 7, mIoU: 0.0191
# Class: 8, mIoU: 0.6881
# Class: 9, mIoU: 0.0264
# Class: 10, mIoU: 0.5532
# Class: 11, mIoU: 0.1039
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.3004
# Class: 14, mIoU: 0.0214
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 12, Loss: 1.3548324480056764, mIoU: 16.31%
# Class: 0, mIoU: 0.4016
# Class: 1, mIoU: 0.0213
# Class: 2, mIoU: 0.5244
# Class: 3, mIoU: 0.0301
# Class: 4, mIoU: 0.0118
# Class: 5, mIoU: 0.1118
# Class: 6, mIoU: 0.0800
# Class: 7, mIoU: 0.0603
# Class: 8, mIoU: 0.6846
# Class: 9, mIoU: 0.0565
# Class: 10, mIoU: 0.5666
# Class: 11, mIoU: 0.1743
# Class: 12, mIoU: 0.0099
# Class: 13, mIoU: 0.3366
# Class: 14, mIoU: 0.0196
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0046
# Class: 17, mIoU: 0.0042
# Class: 18, mIoU: 0.0005
# Epoch: 13, Loss: 1.938425994873047, mIoU: 16.85%
# Class: 0, mIoU: 0.2272
# Class: 1, mIoU: 0.1276
# Class: 2, mIoU: 0.5944
# Class: 3, mIoU: 0.0469
# Class: 4, mIoU: 0.0417
# Class: 5, mIoU: 0.1187
# Class: 6, mIoU: 0.1259
# Class: 7, mIoU: 0.1089
# Class: 8, mIoU: 0.6853
# Class: 9, mIoU: 0.0698
# Class: 10, mIoU: 0.5714
# Class: 11, mIoU: 0.2127
# Class: 12, mIoU: 0.0247
# Class: 13, mIoU: 0.1880
# Class: 14, mIoU: 0.0328
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0001
# Class: 17, mIoU: 0.0136
# Class: 18, mIoU: 0.0118
# Epoch: 14, Loss: 1.6628368253707886, mIoU: 15.31%
# Class: 0, mIoU: 0.3197
# Class: 1, mIoU: 0.0447
# Class: 2, mIoU: 0.4980
# Class: 3, mIoU: 0.0593
# Class: 4, mIoU: 0.0482
# Class: 5, mIoU: 0.1016
# Class: 6, mIoU: 0.0057
# Class: 7, mIoU: 0.0957
# Class: 8, mIoU: 0.5521
# Class: 9, mIoU: 0.0202
# Class: 10, mIoU: 0.6300
# Class: 11, mIoU: 0.1748
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.3435
# Class: 14, mIoU: 0.0151
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0004
# Class: 18, mIoU: 0.0000
# Epoch: 15, Loss: 1.8303220195770264, mIoU: 12.72%
# Class: 0, mIoU: 0.4203
# Class: 1, mIoU: 0.0024
# Class: 2, mIoU: 0.3629
# Class: 3, mIoU: 0.0138
# Class: 4, mIoU: 0.0126
# Class: 5, mIoU: 0.0778
# Class: 6, mIoU: 0.0478
# Class: 7, mIoU: 0.0926
# Class: 8, mIoU: 0.5236
# Class: 9, mIoU: 0.0455
# Class: 10, mIoU: 0.6200
# Class: 11, mIoU: 0.1153
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.0690
# Class: 14, mIoU: 0.0135
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 16, Loss: 1.384650881767273, mIoU: 17.20%
# Class: 0, mIoU: 0.4397
# Class: 1, mIoU: 0.0224
# Class: 2, mIoU: 0.5920
# Class: 3, mIoU: 0.0170
# Class: 4, mIoU: 0.0522
# Class: 5, mIoU: 0.1115
# Class: 6, mIoU: 0.0339
# Class: 7, mIoU: 0.0837
# Class: 8, mIoU: 0.6645
# Class: 9, mIoU: 0.0348
# Class: 10, mIoU: 0.6008
# Class: 11, mIoU: 0.2115
# Class: 12, mIoU: 0.0027
# Class: 13, mIoU: 0.3661
# Class: 14, mIoU: 0.0351
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0003
# Class: 18, mIoU: 0.0000
# Epoch: 17, Loss: 1.550969211578369, mIoU: 15.97%
# Class: 0, mIoU: 0.3163
# Class: 1, mIoU: 0.0233
# Class: 2, mIoU: 0.5812
# Class: 3, mIoU: 0.0406
# Class: 4, mIoU: 0.0272
# Class: 5, mIoU: 0.1503
# Class: 6, mIoU: 0.0203
# Class: 7, mIoU: 0.0136
# Class: 8, mIoU: 0.6097
# Class: 9, mIoU: 0.0233
# Class: 10, mIoU: 0.5983
# Class: 11, mIoU: 0.1442
# Class: 12, mIoU: 0.0009
# Class: 13, mIoU: 0.4570
# Class: 14, mIoU: 0.0269
# Class: 15, mIoU: 0.0013
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 18, Loss: 1.0797217531204224, mIoU: 18.50%
# Class: 0, mIoU: 0.5798
# Class: 1, mIoU: 0.0170
# Class: 2, mIoU: 0.6162
# Class: 3, mIoU: 0.0645
# Class: 4, mIoU: 0.0662
# Class: 5, mIoU: 0.1031
# Class: 6, mIoU: 0.0950
# Class: 7, mIoU: 0.0595
# Class: 8, mIoU: 0.6974
# Class: 9, mIoU: 0.1026
# Class: 10, mIoU: 0.5859
# Class: 11, mIoU: 0.1389
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.3683
# Class: 14, mIoU: 0.0206
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 19, Loss: 1.327043041229248, mIoU: 17.32%
# Class: 0, mIoU: 0.4196
# Class: 1, mIoU: 0.0077
# Class: 2, mIoU: 0.5855
# Class: 3, mIoU: 0.0526
# Class: 4, mIoU: 0.0775
# Class: 5, mIoU: 0.1213
# Class: 6, mIoU: 0.0831
# Class: 7, mIoU: 0.0738
# Class: 8, mIoU: 0.6819
# Class: 9, mIoU: 0.0709
# Class: 10, mIoU: 0.5956
# Class: 11, mIoU: 0.1798
# Class: 12, mIoU: 0.0025
# Class: 13, mIoU: 0.3172
# Class: 14, mIoU: 0.0191
# Class: 15, mIoU: 0.0034
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 20, Loss: 1.7810040102005005, mIoU: 13.14%
# Class: 0, mIoU: 0.2954
# Class: 1, mIoU: 0.0224
# Class: 2, mIoU: 0.4520
# Class: 3, mIoU: 0.0143
# Class: 4, mIoU: 0.0188
# Class: 5, mIoU: 0.0500
# Class: 6, mIoU: 0.0107
# Class: 7, mIoU: 0.0448
# Class: 8, mIoU: 0.6599
# Class: 9, mIoU: 0.0340
# Class: 10, mIoU: 0.6118
# Class: 11, mIoU: 0.1054
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.1753
# Class: 14, mIoU: 0.0009
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 21, Loss: 1.534229557991028, mIoU: 14.68%
# Class: 0, mIoU: 0.3695
# Class: 1, mIoU: 0.0140
# Class: 2, mIoU: 0.4388
# Class: 3, mIoU: 0.0143
# Class: 4, mIoU: 0.0204
# Class: 5, mIoU: 0.1126
# Class: 6, mIoU: 0.0336
# Class: 7, mIoU: 0.0234
# Class: 8, mIoU: 0.6177
# Class: 9, mIoU: 0.0475
# Class: 10, mIoU: 0.6002
# Class: 11, mIoU: 0.1360
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.3461
# Class: 14, mIoU: 0.0161
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 22, Loss: 1.8894660720825196, mIoU: 15.42%
# Class: 0, mIoU: 0.3549
# Class: 1, mIoU: 0.0326
# Class: 2, mIoU: 0.5439
# Class: 3, mIoU: 0.0241
# Class: 4, mIoU: 0.0073
# Class: 5, mIoU: 0.1032
# Class: 6, mIoU: 0.0607
# Class: 7, mIoU: 0.0450
# Class: 8, mIoU: 0.6462
# Class: 9, mIoU: 0.0313
# Class: 10, mIoU: 0.6043
# Class: 11, mIoU: 0.1972
# Class: 12, mIoU: 0.0013
# Class: 13, mIoU: 0.2588
# Class: 14, mIoU: 0.0189
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 23, Loss: 2.2398731575012207, mIoU: 15.27%
# Class: 0, mIoU: 0.2591
# Class: 1, mIoU: 0.0349
# Class: 2, mIoU: 0.5585
# Class: 3, mIoU: 0.0398
# Class: 4, mIoU: 0.0404
# Class: 5, mIoU: 0.1123
# Class: 6, mIoU: 0.0722
# Class: 7, mIoU: 0.0421
# Class: 8, mIoU: 0.6135
# Class: 9, mIoU: 0.0196
# Class: 10, mIoU: 0.5573
# Class: 11, mIoU: 0.1706
# Class: 12, mIoU: 0.0016
# Class: 13, mIoU: 0.3364
# Class: 14, mIoU: 0.0421
# Class: 15, mIoU: 0.0002
# Class: 16, mIoU: 0.0003
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 24, Loss: 1.7394220972061156, mIoU: 15.30%
# Class: 0, mIoU: 0.3487
# Class: 1, mIoU: 0.0051
# Class: 2, mIoU: 0.3960
# Class: 3, mIoU: 0.0072
# Class: 4, mIoU: 0.0282
# Class: 5, mIoU: 0.1135
# Class: 6, mIoU: 0.0796
# Class: 7, mIoU: 0.0551
# Class: 8, mIoU: 0.6694
# Class: 9, mIoU: 0.0456
# Class: 10, mIoU: 0.5456
# Class: 11, mIoU: 0.1986
# Class: 12, mIoU: 0.0012
# Class: 13, mIoU: 0.3857
# Class: 14, mIoU: 0.0272
# Class: 15, mIoU: 0.0010
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 25, Loss: 1.979620087623596, mIoU: 14.15%
# Class: 0, mIoU: 0.2791
# Class: 1, mIoU: 0.0148
# Class: 2, mIoU: 0.5077
# Class: 3, mIoU: 0.0365
# Class: 4, mIoU: 0.0368
# Class: 5, mIoU: 0.0788
# Class: 6, mIoU: 0.0211
# Class: 7, mIoU: 0.0509
# Class: 8, mIoU: 0.6625
# Class: 9, mIoU: 0.0778
# Class: 10, mIoU: 0.5860
# Class: 11, mIoU: 0.1074
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.2025
# Class: 14, mIoU: 0.0259
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 26, Loss: 1.586915358543396, mIoU: 14.61%
# Class: 0, mIoU: 0.4013
# Class: 1, mIoU: 0.0130
# Class: 2, mIoU: 0.4139
# Class: 3, mIoU: 0.0091
# Class: 4, mIoU: 0.0208
# Class: 5, mIoU: 0.1141
# Class: 6, mIoU: 0.0509
# Class: 7, mIoU: 0.0421
# Class: 8, mIoU: 0.6523
# Class: 9, mIoU: 0.0614
# Class: 10, mIoU: 0.5854
# Class: 11, mIoU: 0.1112
# Class: 12, mIoU: 0.0008
# Class: 13, mIoU: 0.2711
# Class: 14, mIoU: 0.0277
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 27, Loss: 1.9032320079803466, mIoU: 14.59%
# Class: 0, mIoU: 0.3052
# Class: 1, mIoU: 0.0072
# Class: 2, mIoU: 0.4752
# Class: 3, mIoU: 0.0168
# Class: 4, mIoU: 0.0396
# Class: 5, mIoU: 0.1069
# Class: 6, mIoU: 0.0269
# Class: 7, mIoU: 0.0485
# Class: 8, mIoU: 0.6558
# Class: 9, mIoU: 0.0292
# Class: 10, mIoU: 0.5303
# Class: 11, mIoU: 0.1721
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.3296
# Class: 14, mIoU: 0.0275
# Class: 15, mIoU: 0.0013
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 28, Loss: 1.9691654176712037, mIoU: 15.38%
# Class: 0, mIoU: 0.3215
# Class: 1, mIoU: 0.0124
# Class: 2, mIoU: 0.5602
# Class: 3, mIoU: 0.0553
# Class: 4, mIoU: 0.0622
# Class: 5, mIoU: 0.1263
# Class: 6, mIoU: 0.0487
# Class: 7, mIoU: 0.1106
# Class: 8, mIoU: 0.5932
# Class: 9, mIoU: 0.0362
# Class: 10, mIoU: 0.5977
# Class: 11, mIoU: 0.1378
# Class: 12, mIoU: 0.0021
# Class: 13, mIoU: 0.2203
# Class: 14, mIoU: 0.0332
# Class: 15, mIoU: 0.0019
# Class: 16, mIoU: 0.0030
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 29, Loss: 2.222431266784668, mIoU: 13.37%
# Class: 0, mIoU: 0.2837
# Class: 1, mIoU: 0.0279
# Class: 2, mIoU: 0.4512
# Class: 3, mIoU: 0.0041
# Class: 4, mIoU: 0.0159
# Class: 5, mIoU: 0.1104
# Class: 6, mIoU: 0.0026
# Class: 7, mIoU: 0.0242
# Class: 8, mIoU: 0.6759
# Class: 9, mIoU: 0.0626
# Class: 10, mIoU: 0.5873
# Class: 11, mIoU: 0.1017
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.1614
# Class: 14, mIoU: 0.0312
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 30, Loss: 1.8514509716033936, mIoU: 15.45%
# Class: 0, mIoU: 0.3512
# Class: 1, mIoU: 0.0285
# Class: 2, mIoU: 0.5564
# Class: 3, mIoU: 0.0351
# Class: 4, mIoU: 0.0161
# Class: 5, mIoU: 0.0892
# Class: 6, mIoU: 0.0512
# Class: 7, mIoU: 0.0549
# Class: 8, mIoU: 0.6668
# Class: 9, mIoU: 0.0803
# Class: 10, mIoU: 0.6063
# Class: 11, mIoU: 0.1154
# Class: 12, mIoU: 0.0001
# Class: 13, mIoU: 0.2716
# Class: 14, mIoU: 0.0103
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0023
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 31, Loss: 1.5958534021377564, mIoU: 15.82%
# Class: 0, mIoU: 0.4153
# Class: 1, mIoU: 0.0220
# Class: 2, mIoU: 0.5438
# Class: 3, mIoU: 0.0309
# Class: 4, mIoU: 0.0187
# Class: 5, mIoU: 0.0727
# Class: 6, mIoU: 0.0339
# Class: 7, mIoU: 0.0637
# Class: 8, mIoU: 0.6823
# Class: 9, mIoU: 0.0665
# Class: 10, mIoU: 0.5597
# Class: 11, mIoU: 0.1722
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.3021
# Class: 14, mIoU: 0.0159
# Class: 15, mIoU: 0.0035
# Class: 16, mIoU: 0.0033
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 32, Loss: 1.5485159635543824, mIoU: 15.97%
# Class: 0, mIoU: 0.4478
# Class: 1, mIoU: 0.0157
# Class: 2, mIoU: 0.5406
# Class: 3, mIoU: 0.0211
# Class: 4, mIoU: 0.0162
# Class: 5, mIoU: 0.0857
# Class: 6, mIoU: 0.0104
# Class: 7, mIoU: 0.0543
# Class: 8, mIoU: 0.6675
# Class: 9, mIoU: 0.0697
# Class: 10, mIoU: 0.6047
# Class: 11, mIoU: 0.1633
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.3210
# Class: 14, mIoU: 0.0144
# Class: 15, mIoU: 0.0015
# Class: 16, mIoU: 0.0001
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 33, Loss: 1.568566156387329, mIoU: 15.44%
# Class: 0, mIoU: 0.4191
# Class: 1, mIoU: 0.0160
# Class: 2, mIoU: 0.4555
# Class: 3, mIoU: 0.0105
# Class: 4, mIoU: 0.0483
# Class: 5, mIoU: 0.0701
# Class: 6, mIoU: 0.0539
# Class: 7, mIoU: 0.0748
# Class: 8, mIoU: 0.6782
# Class: 9, mIoU: 0.0717
# Class: 10, mIoU: 0.5571
# Class: 11, mIoU: 0.1093
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.3548
# Class: 14, mIoU: 0.0153
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 34, Loss: 1.56680588722229, mIoU: 15.83%
# Class: 0, mIoU: 0.3889
# Class: 1, mIoU: 0.0386
# Class: 2, mIoU: 0.5241
# Class: 3, mIoU: 0.0285
# Class: 4, mIoU: 0.0414
# Class: 5, mIoU: 0.0806
# Class: 6, mIoU: 0.0114
# Class: 7, mIoU: 0.0561
# Class: 8, mIoU: 0.6825
# Class: 9, mIoU: 0.0539
# Class: 10, mIoU: 0.6137
# Class: 11, mIoU: 0.1693
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.3047
# Class: 14, mIoU: 0.0146
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 35, Loss: 1.4908955779075623, mIoU: 16.06%
# Class: 0, mIoU: 0.4262
# Class: 1, mIoU: 0.0161
# Class: 2, mIoU: 0.5341
# Class: 3, mIoU: 0.0257
# Class: 4, mIoU: 0.0269
# Class: 5, mIoU: 0.0808
# Class: 6, mIoU: 0.0076
# Class: 7, mIoU: 0.0551
# Class: 8, mIoU: 0.7000
# Class: 9, mIoU: 0.0997
# Class: 10, mIoU: 0.6312
# Class: 11, mIoU: 0.1337
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.2973
# Class: 14, mIoU: 0.0120
# Class: 15, mIoU: 0.0048
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 36, Loss: 1.5940858402252198, mIoU: 16.80%
# Class: 0, mIoU: 0.4198
# Class: 1, mIoU: 0.0154
# Class: 2, mIoU: 0.5488
# Class: 3, mIoU: 0.0402
# Class: 4, mIoU: 0.0349
# Class: 5, mIoU: 0.1025
# Class: 6, mIoU: 0.0524
# Class: 7, mIoU: 0.0674
# Class: 8, mIoU: 0.6911
# Class: 9, mIoU: 0.0711
# Class: 10, mIoU: 0.6093
# Class: 11, mIoU: 0.1273
# Class: 12, mIoU: 0.0030
# Class: 13, mIoU: 0.3852
# Class: 14, mIoU: 0.0184
# Class: 15, mIoU: 0.0001
# Class: 16, mIoU: 0.0057
# Class: 17, mIoU: 0.0002
# Class: 18, mIoU: 0.0000
# Epoch: 37, Loss: 2.0829527101516723, mIoU: 11.16%
# Class: 0, mIoU: 0.3363
# Class: 1, mIoU: 0.0181
# Class: 2, mIoU: 0.3637
# Class: 3, mIoU: 0.0043
# Class: 4, mIoU: 0.0195
# Class: 5, mIoU: 0.0635
# Class: 6, mIoU: 0.0213
# Class: 7, mIoU: 0.0017
# Class: 8, mIoU: 0.5484
# Class: 9, mIoU: 0.0433
# Class: 10, mIoU: 0.4584
# Class: 11, mIoU: 0.0088
# Class: 12, mIoU: 0.0008
# Class: 13, mIoU: 0.1900
# Class: 14, mIoU: 0.0284
# Class: 15, mIoU: 0.0087
# Class: 16, mIoU: 0.0006
# Class: 17, mIoU: 0.0040
# Class: 18, mIoU: 0.0000
# Epoch: 38, Loss: 1.809922426223755, mIoU: 14.38%
# Class: 0, mIoU: 0.3700
# Class: 1, mIoU: 0.0203
# Class: 2, mIoU: 0.5738
# Class: 3, mIoU: 0.0210
# Class: 4, mIoU: 0.0043
# Class: 5, mIoU: 0.0865
# Class: 6, mIoU: 0.0128
# Class: 7, mIoU: 0.0181
# Class: 8, mIoU: 0.5550
# Class: 9, mIoU: 0.0283
# Class: 10, mIoU: 0.6047
# Class: 11, mIoU: 0.1247
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.2916
# Class: 14, mIoU: 0.0201
# Class: 15, mIoU: 0.0007
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 39, Loss: 1.8691844377517701, mIoU: 14.64%
# Class: 0, mIoU: 0.3553
# Class: 1, mIoU: 0.0122
# Class: 2, mIoU: 0.4953
# Class: 3, mIoU: 0.0122
# Class: 4, mIoU: 0.0094
# Class: 5, mIoU: 0.0838
# Class: 6, mIoU: 0.0705
# Class: 7, mIoU: 0.0394
# Class: 8, mIoU: 0.6030
# Class: 9, mIoU: 0.0517
# Class: 10, mIoU: 0.6036
# Class: 11, mIoU: 0.1334
# Class: 12, mIoU: 0.0006
# Class: 13, mIoU: 0.2910
# Class: 14, mIoU: 0.0209
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 40, Loss: 1.865775284767151, mIoU: 14.85%
# Class: 0, mIoU: 0.3800
# Class: 1, mIoU: 0.0066
# Class: 2, mIoU: 0.4270
# Class: 3, mIoU: 0.0209
# Class: 4, mIoU: 0.0183
# Class: 5, mIoU: 0.0719
# Class: 6, mIoU: 0.0425
# Class: 7, mIoU: 0.0310
# Class: 8, mIoU: 0.6455
# Class: 9, mIoU: 0.0563
# Class: 10, mIoU: 0.5991
# Class: 11, mIoU: 0.1482
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.3529
# Class: 14, mIoU: 0.0186
# Class: 15, mIoU: 0.0028
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 41, Loss: 2.0361716537475587, mIoU: 14.81%
# Class: 0, mIoU: 0.3194
# Class: 1, mIoU: 0.0077
# Class: 2, mIoU: 0.5301
# Class: 3, mIoU: 0.0137
# Class: 4, mIoU: 0.0081
# Class: 5, mIoU: 0.0547
# Class: 6, mIoU: 0.0283
# Class: 7, mIoU: 0.0404
# Class: 8, mIoU: 0.6182
# Class: 9, mIoU: 0.0278
# Class: 10, mIoU: 0.6225
# Class: 11, mIoU: 0.1510
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.3792
# Class: 14, mIoU: 0.0121
# Class: 15, mIoU: 0.0001
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 42, Loss: 1.884328176498413, mIoU: 14.83%
# Class: 0, mIoU: 0.3528
# Class: 1, mIoU: 0.0179
# Class: 2, mIoU: 0.4638
# Class: 3, mIoU: 0.0261
# Class: 4, mIoU: 0.0388
# Class: 5, mIoU: 0.0829
# Class: 6, mIoU: 0.0278
# Class: 7, mIoU: 0.0258
# Class: 8, mIoU: 0.6507
# Class: 9, mIoU: 0.0604
# Class: 10, mIoU: 0.5817
# Class: 11, mIoU: 0.1303
# Class: 12, mIoU: 0.0007
# Class: 13, mIoU: 0.3417
# Class: 14, mIoU: 0.0120
# Class: 15, mIoU: 0.0039
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0010
# Class: 18, mIoU: 0.0000
# Epoch: 43, Loss: 1.757683819770813, mIoU: 15.34%
# Class: 0, mIoU: 0.4033
# Class: 1, mIoU: 0.0259
# Class: 2, mIoU: 0.5165
# Class: 3, mIoU: 0.0194
# Class: 4, mIoU: 0.0330
# Class: 5, mIoU: 0.0703
# Class: 6, mIoU: 0.0090
# Class: 7, mIoU: 0.0490
# Class: 8, mIoU: 0.6226
# Class: 9, mIoU: 0.0476
# Class: 10, mIoU: 0.6271
# Class: 11, mIoU: 0.1419
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.3225
# Class: 14, mIoU: 0.0263
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 44, Loss: 2.0875642223358155, mIoU: 14.51%
# Class: 0, mIoU: 0.3227
# Class: 1, mIoU: 0.0088
# Class: 2, mIoU: 0.4522
# Class: 3, mIoU: 0.0225
# Class: 4, mIoU: 0.0750
# Class: 5, mIoU: 0.0647
# Class: 6, mIoU: 0.0040
# Class: 7, mIoU: 0.0457
# Class: 8, mIoU: 0.6912
# Class: 9, mIoU: 0.0687
# Class: 10, mIoU: 0.6156
# Class: 11, mIoU: 0.0813
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.2899
# Class: 14, mIoU: 0.0138
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 45, Loss: 1.7934751625061036, mIoU: 15.76%
# Class: 0, mIoU: 0.3605
# Class: 1, mIoU: 0.0389
# Class: 2, mIoU: 0.5245
# Class: 3, mIoU: 0.0376
# Class: 4, mIoU: 0.0645
# Class: 5, mIoU: 0.0632
# Class: 6, mIoU: 0.0234
# Class: 7, mIoU: 0.0510
# Class: 8, mIoU: 0.7021
# Class: 9, mIoU: 0.0454
# Class: 10, mIoU: 0.5789
# Class: 11, mIoU: 0.1258
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.3564
# Class: 14, mIoU: 0.0218
# Class: 15, mIoU: 0.0010
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 46, Loss: 1.82380393409729, mIoU: 15.45%
# Class: 0, mIoU: 0.3749
# Class: 1, mIoU: 0.0158
# Class: 2, mIoU: 0.4653
# Class: 3, mIoU: 0.0353
# Class: 4, mIoU: 0.0275
# Class: 5, mIoU: 0.0878
# Class: 6, mIoU: 0.0102
# Class: 7, mIoU: 0.0454
# Class: 8, mIoU: 0.6990
# Class: 9, mIoU: 0.0775
# Class: 10, mIoU: 0.5961
# Class: 11, mIoU: 0.1625
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.3222
# Class: 14, mIoU: 0.0122
# Class: 15, mIoU: 0.0033
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 47, Loss: 2.275245015144348, mIoU: 13.86%
# Class: 0, mIoU: 0.3049
# Class: 1, mIoU: 0.0173
# Class: 2, mIoU: 0.4932
# Class: 3, mIoU: 0.0107
# Class: 4, mIoU: 0.0064
# Class: 5, mIoU: 0.0685
# Class: 6, mIoU: 0.0099
# Class: 7, mIoU: 0.0454
# Class: 8, mIoU: 0.6604
# Class: 9, mIoU: 0.0766
# Class: 10, mIoU: 0.5122
# Class: 11, mIoU: 0.1128
# Class: 12, mIoU: 0.0018
# Class: 13, mIoU: 0.3060
# Class: 14, mIoU: 0.0079
# Class: 15, mIoU: 0.0000
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0000
# Class: 18, mIoU: 0.0000
# Epoch: 48, Loss: 2.7355974445343016, mIoU: 13.07%
# Class: 0, mIoU: 0.2535
# Class: 1, mIoU: 0.0156
# Class: 2, mIoU: 0.3473
# Class: 3, mIoU: 0.0129
# Class: 4, mIoU: 0.0108
# Class: 5, mIoU: 0.0443
# Class: 6, mIoU: 0.0123
# Class: 7, mIoU: 0.0134
# Class: 8, mIoU: 0.6301
# Class: 9, mIoU: 0.0662
# Class: 10, mIoU: 0.6182
# Class: 11, mIoU: 0.1566
# Class: 12, mIoU: 0.0000
# Class: 13, mIoU: 0.2815
# Class: 14, mIoU: 0.0098
# Class: 15, mIoU: 0.0111
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0003
# Class: 18, mIoU: 0.0000
# Epoch: 49, Loss: 1.6439043521881103, mIoU: 15.46%
# Class: 0, mIoU: 0.3346
# Class: 1, mIoU: 0.0374
# Class: 2, mIoU: 0.5011
# Class: 3, mIoU: 0.0247
# Class: 4, mIoU: 0.0296
# Class: 5, mIoU: 0.0981
# Class: 6, mIoU: 0.0497
# Class: 7, mIoU: 0.0529
# Class: 8, mIoU: 0.6865
# Class: 9, mIoU: 0.0465
# Class: 10, mIoU: 0.6334
# Class: 11, mIoU: 0.1684
# Class: 12, mIoU: 0.0011
# Class: 13, mIoU: 0.2097
# Class: 14, mIoU: 0.0570
# Class: 15, mIoU: 0.0065
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0003
# Class: 18, mIoU: 0.0000
# Epoch: 50, Loss: 1.9056049556732177, mIoU: 16.01%
# Class: 0, mIoU: 0.3002
# Class: 1, mIoU: 0.0166
# Class: 2, mIoU: 0.5212
# Class: 3, mIoU: 0.0337
# Class: 4, mIoU: 0.0588
# Class: 5, mIoU: 0.1162
# Class: 6, mIoU: 0.0827
# Class: 7, mIoU: 0.0639
# Class: 8, mIoU: 0.6989
# Class: 9, mIoU: 0.0453
# Class: 10, mIoU: 0.6103
# Class: 11, mIoU: 0.2112
# Class: 12, mIoU: 0.0005
# Class: 13, mIoU: 0.2527
# Class: 14, mIoU: 0.0223
# Class: 15, mIoU: 0.0008
# Class: 16, mIoU: 0.0000
# Class: 17, mIoU: 0.0060
# Class: 18, mIoU: 0.0000
# [INFO] Total training time: 262268.647 seconds
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>train/Batch loss</td><td>█▆▆▅▄▃▄▂▃▃▃▃▂▃▂▂▂▁▂▂▂▂▂▂▂▂▁▂▁▂▁▂▁▁▁▁▁▁▄▁</td></tr><tr><td>train/Epoch loss</td><td>█▅▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▂▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/Validation loss</td><td>▁▃▄▆▂▂▂▁▃▂▅▃▂▃▁▂▃▄▆▄▃▄▅▆▃▃▃▃▃▅▄▄▅▄▄▅▄▆█▄</td></tr><tr><td>val/mIoU</td><td>▅▃▂▄▅▆▅▇▄▆▆▅▇▆█▇▄▅▅▅▄▄▅▃▅▆▅▅▆▁▄▄▄▅▅▄▅▄▃▆</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Epoch</td><td>50</td></tr><tr><td>train/Batch loss</td><td>0.11466</td></tr><tr><td>train/Epoch loss</td><td>0.11535</td></tr><tr><td>val/Validation loss</td><td>1.9056</td></tr><tr><td>val/mIoU</td><td>0.16007</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">horizFlip_rc</strong> at: <a href='https://wandb.ai/porta-luca/bisenet_gta/runs/bp6xowec' target="_blank">https://wandb.ai/porta-luca/bisenet_gta/runs/bp6xowec</a><br/> View project at: <a href='https://wandb.ai/porta-luca/bisenet_gta' target="_blank">https://wandb.ai/porta-luca/bisenet_gta</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20240629_135848-bp6xowec\logs</code>
